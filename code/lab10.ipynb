# %%
import numpy as np

# %%
# Ex1
A = np.array([[-1,3.5,14],
              [0,5,-26],
              [0,0,2]])

B = np.array([[-2,0,0],
              ])
eigenvalues, eigenvectors = np.linalg.eig(A)
det_A = np.prod(eigenvalues)
det_A
# Out:
# -10.0
